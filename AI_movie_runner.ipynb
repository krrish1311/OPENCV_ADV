# %%
import mediapipe as mp
import numpy as np
import HandDetectormymodule as hdm
import cv2
import time 
import math
import os

wcam=640
hcam=480

ctime=0
ptime=0
detector =hdm.handdetector(detconf=0.6)

cap=cv2.VideoCapture(0)
#cap=cv2.VideoCapture('http://192.168.43.1:8080/video')
cap.set(3,wcam)
cap.set(3,hcam)
fore=0
thumb=0
middle=0
ring=0
little=0


while True:
    ret,image = cap.read()
    img=cv2.resize(image,(640,480))
    img=detector.find_hands(img)
    lmlist=detector.find_positions(img,draw=False)
    if len(lmlist) != 0:
        x0,y0=lmlist[2][1],lmlist[2][2]
        x02,y02=lmlist[4][1],lmlist[4][2]
        x1,y1=lmlist[5][1],lmlist[5][2]
        x2,y2=lmlist[8][1],lmlist[8][2]
        x3,y3=lmlist[9][1],lmlist[9][2]
        x4,y4=lmlist[12][1],lmlist[12][2]
        x5,y5=lmlist[13][1],lmlist[13][2]
        x6,y6=lmlist[16][1],lmlist[16][2]
        x7,y7=lmlist[17][1],lmlist[17][2]
        x8,y8=lmlist[20][1],lmlist[20][2]
        
        
        thumb=math.hypot(x02-x0 , y02-y0)
        fore=math.hypot(x2-x1 , y2-y1)
        middle=math.hypot(x4-x3 , y4-y3)
        ring=math.hypot(x6-x5 , y6-y5)
        little=math.hypot(x8-x7 , y8-y7)
        cv2.line(img,(x1,y1),(x2,y2),(0,0,0),3)
        cv2.line(img,(x3,y3),(x4,y4),(0,0,0),3)
        cv2.line(img,(x5,y5),(x6,y6),(0,0,0),3)
        cv2.line(img,(x7,y7),(x8,y8),(0,0,0),3)

        
        #print('thumb',int(thumb),'fore' ,int(fore) ,'middle',int(middle),'ring' ,int(ring),'liitle',int(little),sep='\t')
    #time.sleep(2)    
    cv2.imshow('image',img)
    
    if int(fore) > 165 and int(thumb) > 80 and int(middle) > 185 and int(ring) > 175 and int(little) > 140 :
        os.system('vlc "D:\Entertainment\Hollywood\Cristopher Nolan\The Prestige"')
        
        cv2.destroyAllWindows()
        break
        
    elif int(fore) > 170  and int(middle) > 190 and int(ring) > 180 and int(little) > 145 :
        os.system('vlc "D:\Entertainment\Hollywood\Cristopher Nolan\Dark Knight" ')
        cv2.destroyAllWindows()
        break
        time.sleep(3)
        
    elif int(fore) > 180  and int(middle) > 200 and int(ring) > 190 :
        os.system('vlc "D:\Entertainment\Hollywood\Cristopher Nolan\TENET(2020)[1080p]"')
        
        cv2.destroyAllWindows()
        break
        
        
    elif int(fore) > 180  and int(middle) > 200  :
        os.system('vlc "D:\Entertainment\hollywood\Cristopher Nolan\Inception (2010) [1080p]"')
        
        cv2.destroyAllWindows()
        break
        
    elif int(fore) > 180 :
        os.system('vlc "D:\Entertainment\hollywood\Cristopher Nolan\Interstellar (2014)[1080p]" ')
        
        cv2.destroyAllWindows()
        break
  
    else:
        pass

        
    
    if cv2.waitKey(1)==13:
        cv2.destroyAllWindows()
        break

# %%
import mediapipe as mp
import numpy as np
import HandDetectormymodule as hdm
import cv2
import time 
import math
import os

# %%
wcam=640
hcam=480

ctime=0
ptime=0
detector =hdm.handdetector(detconf=0.6)

#cap=cv2.VideoCapture(0)
cap=cv2.VideoCapture('http://192.168.43.1:8080/video')
cap.set(3,wcam)
cap.set(3,hcam)
fore=0
thumb=0
middle=0
ring=0
little=0

# %%
while True:
    ret,image = cap.read()
    img=cv2.resize(image,(640,480))
    img=detector.find_hands(img)
    lmlist=detector.find_positions(img,draw=False)
    if len(lmlist) != 0:
        x0,y0=lmlist[2][1],lmlist[2][2]
        x02,y02=lmlist[4][1],lmlist[4][2]
        x1,y1=lmlist[5][1],lmlist[5][2]
        x2,y2=lmlist[8][1],lmlist[8][2]
        x3,y3=lmlist[9][1],lmlist[9][2]
        x4,y4=lmlist[12][1],lmlist[12][2]
        x5,y5=lmlist[13][1],lmlist[13][2]
        x6,y6=lmlist[16][1],lmlist[16][2]
        x7,y7=lmlist[17][1],lmlist[17][2]
        x8,y8=lmlist[20][1],lmlist[20][2]
        
        
        thumb=math.hypot(x02-x0 , y02-y0)
        fore=math.hypot(x2-x1 , y2-y1)
        middle=math.hypot(x4-x3 , y4-y3)
        ring=math.hypot(x6-x5 , y6-y5)
        little=math.hypot(x8-x7 , y8-y7)
        cv2.line(img,(x1,y1),(x2,y2),(0,0,0),3)
        cv2.line(img,(x3,y3),(x4,y4),(0,0,0),3)
        cv2.line(img,(x5,y5),(x6,y6),(0,0,0),3)
        cv2.line(img,(x7,y7),(x8,y8),(0,0,0),3)

        
        #print('thumb',int(thumb),'fore' ,int(fore) ,'middle',int(middle),'ring' ,int(ring),'liitle',int(little),sep='\t')
    #time.sleep(2)    
    cv2.imshow('image',img)
    
    if int(fore) > 165 and int(thumb) > 90 and int(middle) > 185 and int(ring) > 175 and int(little) > 140 :
        os.system('vlc "D:\Entertainment\Hollywood\Cristopher Nolan\The Prestige"')
        
        cv2.destroyAllWindows()
        break
        
    elif int(fore) > 170  and int(middle) > 190 and int(ring) > 180 and int(little) > 145 :
        os.system('vlc "D:\Entertainment\Hollywood\Cristopher Nolan\Dark Knight" ')
        cv2.destroyAllWindows()
        break
        time.sleep(3)
        
    elif int(fore) > 180  and int(middle) > 200 and int(ring) > 190 :
        os.system('vlc "D:\Entertainment\Hollywood\Cristopher Nolan\TENET(2020)[1080p]"')
        
        cv2.destroyAllWindows()
        break
        
        
    elif int(fore) > 180  and int(middle) > 190  :
        os.system('vlc "D:\Entertainment\hollywood\Cristopher Nolan\Inception (2010) [1080p]"')
        
        cv2.destroyAllWindows()
        break
        
    elif int(fore) > 185 :
        os.system('vlc "D:\Entertainment\hollywood\Cristopher Nolan\Interstellar (2014)[1080p]" ')
        
        cv2.destroyAllWindows()
        break
  
    else:
        pass

        
    
    if cv2.waitKey(1)==13:
        cv2.destroyAllWindows()
        break

# %%
cap.release()
